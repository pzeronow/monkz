# %%
import matplotlib.pyplot as plt
import numpy as np
import random
print('helloooou')
# Out:
# helloooou

# %%
print('LOL!')
tau = 1000
X = []
Y = []
t_a = 0
t_b = 0

for t in range(0, tau):
    t_a += random.randint(-1, 1)
    t_b += random.randint(-1, 1)
    X.append(t_a)
    Y.append(t_b)

print(X)
print(Y)
plt.scatter(X,Y)
plt.show()
# Out:
# LOL!
# ...
